# %%
import numpy as np
import pandas as pd
import os

# %%
os.listdir('../datasets')
# Out:
# ['home_value_data.csv']

# %%
df = pd.read_csv('../datasets/home_value_data.csv')
df.head()
# Out:
#    zip_code     city state                     metro       county     date  \
# 0     60657  Chicago    IL  Chicago-Naperville-Elgin  Cook County  1996-04
# 1     60657  Chicago    IL  Chicago-Naperville-Elgin  Cook County  1996-05
# 2     60657  Chicago    IL  Chicago-Naperville-Elgin  Cook County  1996-06
# 3     60657  Chicago    IL  Chicago-Naperville-Elgin  Cook County  1996-07
# 4     60657  Chicago    IL  Chicago-Naperville-Elgin  Cook County  1996-08
#
#       value
# 0  334200.0
# 1  335400.0
# 2  336500.0
# 3  337600.0
# 4  338500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4202944 entries, 0 to 4202943
# Data columns (total 7 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   zip_code  int64
#  1   city      object
#  2   state     object
#  3   metro     object
#  4   county    object
#  5   date      object
#  6   value     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 224.5+ MB

# %%
df.zip_code = df.zip_code.astype(str)

# %%
df.value.value_counts()
# Out:
# 85100.0      2611
# 89000.0      2589
# 88200.0      2568
# 89400.0      2564
# 84700.0      2560
#              ...
# 2229300.0       1
# 2229100.0       1
# 2229000.0       1
# 2228800.0       1
# 2001400.0       1
# Name: value, Length: 24969, dtype: int64

# %%
df.date.min(), df.date.max()
# Out:
# ('1996-04', '2018-11')

# %%
dfs = []
ranges = []

for i in range(0, len(df), 500000):
    print(i)
    x, y = i, (i + 500001)
    print(x, y)
    ranges.append((x, y))
    df = 'df_' + str(y)
    dfs.append(df)
# Out:
# 0
# 0 500001
# 500000
# 500000 1000001
# 1000000
# 1000000 1500001
# 1500000
# 1500000 2000001
# 2000000
# 2000000 2500001
# 2500000
# 2500000 3000001
# 3000000
# 3000000 3500001
# 3500000
# 3500000 4000001
# 4000000
# 4000000 4500001

# %%
dfs
# Out:
# ['df_500001',
#  'df_1000001',
#  'df_1500001',
#  'df_2000001',
#  'df_2500001',
#  'df_3000001',
#  'df_3500001',
#  'df_4000001',
#  'df_4500001']

# %%
ranges
# Out:
# [(0, 500001),
#  (500000, 1000001),
#  (1000000, 1500001),
#  (1500000, 2000001),
#  (2000000, 2500001),
#  (2500000, 3000001),
#  (3000000, 3500001),
#  (3500000, 4000001),
#  (4000000, 4500001)]

# %%
dictionary = {}

for i in range(0, len(df), 500000):
    x, y = i, (i + 500001)
    df_name = 'df_' + str(y)
    dictionary.update({df_name: (x, y)})

# %%
dictionary
# Out:
# {'df_500001': (0, 500001),
#  'df_1000001': (500000, 1000001),
#  'df_1500001': (1000000, 1500001),
#  'df_2000001': (1500000, 2000001),
#  'df_2500001': (2000000, 2500001),
#  'df_3000001': (2500000, 3000001),
#  'df_3500001': (3000000, 3500001),
#  'df_4000001': (3500000, 4000001),
#  'df_4500001': (4000000, 4500001)}

# %%
for key, value in dictionary:
    key =

# %%
dictionary.items()
# Out:
# dict_items([('df_500001', (0, 500001)), ('df_1000001', (500000, 1000001)), ('df_1500001', (1000000, 1500001)), ('df_2000001', (1500000, 2000001)), ('df_2500001', (2000000, 2500001)), ('df_3000001', (2500000, 3000001)), ('df_3500001', (3000000, 3500001)), ('df_4000001', (3500000, 4000001)), ('df_4500001', (4000000, 4500001))])

# %%
for item in dictionary.items():
    something =
# Out:
# ('df_500001', (0, 500001))
# ('df_1000001', (500000, 1000001))
# ('df_1500001', (1000000, 1500001))
# ('df_2000001', (1500000, 2000001))
# ('df_2500001', (2000000, 2500001))
# ('df_3000001', (2500000, 3000001))
# ('df_3500001', (3000000, 3500001))
# ('df_4000001', (3500000, 4000001))
# ('df_4500001', (4000000, 4500001))

# %%
print('hello')
# Out:
# hello

# %%
hello = 1

# %%
eval('hello')
# Out:
# 1

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import numpy as np\nimport pandas as pd\nimport os',
#   'os.listdir()',
#   "os.listdir('..')",
#   "os.listdir('../datasets')",
#   "df = pd.read_csv('../datasets/home_value_data.csv')\ndf.head()",
#   'df.info()',
#   'df.zip_code = df.zip_code.astype(str)',
#   'df.info()',
#   'df.date = pd.to_datetime(df.date, format=%y%m)',
#   'df.date = pd.to_datetime(df.date, format=%Y%m)',
#   'df.value.value_counts()',
#   'df.date.min()',
#   'df.date.min(), df.date.max()',
#   'df[1]',
#   'df[1:7]',
#   'range(0,10,2)',
#   'x = range(0,10,2)\nx',
#   'x = range(0,10,2)\nprint(x)',
#   'for i in range(0,10,2):\n    print(i)',
#   'for i in range(0,len(df),1000000):\n    print(i)',
# ...

# %%
print('iWantAVariableWithThisName' in locals())
junkVar = 'iWantAVariableWithThisName'
exec(junkVar + " = 1")
print('iWantAVariableWithThisName' in locals())
# Out:
# False
# True

# %%
iWantAVariableWithThisName
# Out:
# 1

# %%
junk2 = 'dictionary_key'
exec(junk2 + '= 1')

# %%
dictionary_key
# Out:
# 1

# %%
# final version
junk3 = 'dictionary_key2'
exec(junk3 + '= df[0:500001]')

df[value[0]:value[1]]

# %%
junk3
# Out:
# 'dictionary_key2'

# %%
dictionary_key2
# Out:
#        zip_code     city state                        metro         county  \
# 0         60657  Chicago    IL     Chicago-Naperville-Elgin    Cook County
# 1         60657  Chicago    IL     Chicago-Naperville-Elgin    Cook County
# 2         60657  Chicago    IL     Chicago-Naperville-Elgin    Cook County
# 3         60657  Chicago    IL     Chicago-Naperville-Elgin    Cook County
# 4         60657  Chicago    IL     Chicago-Naperville-Elgin    Cook County
# ...         ...      ...   ...                          ...            ...
# 499996    75075    Plano    TX  Dallas-Fort Worth-Arlington  Collin County
# 499997    75075    Plano    TX  Dallas-Fort Worth-Arlington  Collin County
# 499998    75075    Plano    TX  Dallas-Fort Worth-Arlington  Collin County
# 499999    75075    Plano    TX  Dallas-Fort Worth-Arlington  Collin County
# 500000    75075    Plano    TX  Dallas-Fort Worth-Arlington  Collin County
#
#            date     value
# 0       1996-04  334200.0
# ...

# %%
for each key value pair in my dictionary:
    junkvar = 'dictionary_key'
    exec(junkvar + 'df[{value[0]}: {value[1]}]')
